# %% [markdown]
# # Overview
# In this data modeling project, we will be working with a dataset from King County, which contains information about house sales. The dataset is available on Kaggle and includes various features related to houses in the area, such as the number of bedrooms, bathrooms, the square footage, condition, and location. Our goal is to analyze this data and develop a model that can accurately predict the prices of houses in King County based on the given features. By doing so, we aim to provide valuable insights to potential buyers, sellers, and real estate agents in the region.

# %% [markdown]
# # Business Understanding:
# Understanding the factors that influence house prices is crucial for various stakeholders in the real estate market. For potential buyers, having accurate predictions of house prices can help them make informed decisions when considering a purchase. Sellers can benefit from understanding the factors that drive prices higher and strategically pricing their properties. Real estate agents can use such a model to assist their clients by providing accurate pricing estimates and identifying potential investment opportunities.

# %% [markdown]
# # Data Understanding:
# The dataset from King County contains a comprehensive set of features related to house sales. Each data point represents a unique house sale and includes information such as the number of bedrooms, bathrooms, square footage, condition, and location details etc. Additional features include the year of construction, renovation, and the grade assigned to the house. By analyzing this data, we can gain insights into how these features impact the sale price of houses in the area.

# %% [markdown]
# ## Column Names and Descriptions for King County Data Set
# * `id` - Unique identifier for a house
# * `date` - Date house was sold
# * `price` - Sale price (prediction target)
# * `bedrooms` - Number of bedrooms
# * `bathrooms` - Number of bathrooms
# * `sqft_living` - Square footage of living space in the home
# * `sqft_lot` - Square footage of the lot
# * `floors` - Number of floors (levels) in house
# * `waterfront` - Whether the house is on a waterfront
#   * Includes Duwamish, Elliott Bay, Puget Sound, Lake Union, Ship Canal, Lake Washington, Lake Sammamish, other lake, and river/slough waterfronts
# * `view` - Quality of view from house
#   * Includes views of Mt. Rainier, Olympics, Cascades, Territorial, Seattle Skyline, Puget Sound, Lake Washington, Lake Sammamish, small lake / river / creek, and other
# * `condition` - How good the overall condition of the house is. Related to maintenance of house.
#   * See the [King County Assessor Website](https://info.kingcounty.gov/assessor/esales/Glossary.aspx?type=r) for further explanation of each condition code
# * `grade` - Overall grade of the house. Related to the construction and design of the house.
#   * See the [King County Assessor Website](https://info.kingcounty.gov/assessor/esales/Glossary.aspx?type=r) for further explanation of each building grade code
# * `sqft_above` - Square footage of house apart from basement
# * `sqft_basement` - Square footage of the basement
# * `yr_built` - Year when house was built
# * `yr_renovated` - Year when house was renovated
# * `zipcode` - ZIP Code used by the United States Postal Service
# * `lat` - Latitude coordinate
# * `long` - Longitude coordinate
# * `sqft_living15` - The square footage of interior housing living space for the nearest 15 neighbors
# * `sqft_lot15` - The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# # Objectives of the Project:
#
# 1. Develop a predictive model: The primary objective of this project is to develop a robust predictive model that can accurately estimate house prices in King County. By analyzing the available dataset and utilizing appropriate machine learning techniques, we aim to create a model that can effectively predict house prices based on various features such as the number of bedrooms, bathrooms, square footage, condition, and location.
#
# 2. Identify significant predictors: Through exploratory data analysis (EDA) and feature importance analysis, we aim to identify the key factors that significantly influence house prices in King County. By understanding the relative importance of different features, we can provide valuable insights into what aspects potential buyers and sellers should consider when pricing or purchasing a house.
#
# 3. Provide recommendations for pricing strategies: Based on the analysis of the dataset and the developed predictive model, we aim to provide recommendations for pricing strategies to both sellers and real estate agents. These recommendations will be based on the identified predictors and insights derived from the model, enabling sellers to strategically price their properties and assisting agents in providing accurate pricing estimates to their clients.
#
# 4. Assess model performance and accuracy: It is important to evaluate the performance and accuracy of the developed predictive model. We will assess the model's predictive capabilities by comparing the predicted house prices with the actual sale prices from the dataset. Through appropriate evaluation metrics, such as mean absolute error (MAE) or root mean squared error (RMSE), we will determine the model's accuracy and its ability to generalize to unseen data.
#
# 5. Communicate insights and findings: Another objective of this project is to effectively communicate the insights and findings derived from the analysis. We aim to present the results in a clear and concise manner, utilizing visualizations and descriptive explanations. By doing so, we can ensure that the stakeholders, including potential buyers, sellers, and real estate agents, can easily understand and benefit from the information provided by the predictive model.
#
#
# By achieving these objectives, this project aims to contribute to the understanding of house price dynamics in King County and provide valuable guidance to stakeholders involved in the real estate market.

# %% [markdown]
# # Data Preparation:
# Before conducting exploratory data analysis and modeling, we need to prepare the dataset. This involves several steps, including:
#
# 1. Loading the dataset: We will import the dataset into our analysis environment and examine its structure and format.
# 2. Data cleaning: We will identify and handle missing values, outliers, and inconsistencies in the dataset. This step ensures that our analysis is based on reliable and accurate data.
# 3. Feature engineering: We will explore the possibility of creating new features from the existing ones to capture additional information. For example, we could derive the age of a house by subtracting the year of construction from the current year.
# 4. Data normalization: If necessary, we will scale or transform certain features to ensure that they are on a similar scale and adhere to the assumptions of the modeling techniques we plan to use.
# 5. Splitting the dataset: To evaluate the performance of our model, we will divide the dataset into training and testing sets. The training set will be used to train the model, while the testing set will be used to assess its predictive accuracy.
#
# By completing these steps, we will have a clean and prepared dataset that is ready for exploratory data analysis and subsequent modeling to predict house prices in King County.

# %%
#Import the necesary libraries
import pandas as pdov
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Part 1 Loading the dataset

# %%
#Lets load the dataset
data = pd.read_csv('kc_house_data.csv')

# %%
data.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0      5650     1.0        NaN  NONE  ...      7 Average       1180
# 1      7242     2.0         NO  NONE  ...      7 Average       2170
# 2     10000     1.0         NO  NONE  ...  6 Low Average        770
# 3      5000     1.0         NO  NONE  ...      7 Average       1050
# 4      8080     1.0         NO  NONE  ...         8 Good       1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.tail()
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...      grade sqft_above  \
# 21592      1131     3.0         NO  NONE  ...     8 Good       1530
# 21593      5813     2.0         NO  NONE  ...     8 Good       2310
# 21594      1350     2.0         NO  NONE  ...  7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...     8 Good       1600
# 21596      1076     2.0         NO  NONE  ...  7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.sample
# Out:
# <bound method NDFrame.sample of                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
# ...

# %%
data.shape
# Out:
# (21597, 21)

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# ...

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# sqft_above    -0.010799  0.605368  0.479386   0.686668     0.876448  0.184139
# yr_built       0.021617  0.053953  0.155670   0.507173     0.318152  0.052946
# yr_renovated  -0.012010  0.129599  0.018495   0.051050     0.055660  0.004513
# zipcode       -0.008211 -0.053402 -0.154092  -0.204786    -0.199802 -0.129586
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
plt.figure(figsize=(6,4))
sns.boxplot(y=data['price']).set_title
plt.show()

# %%
#print highly correlated variables
corr_features =[]

for i , r in data.corr().iterrows():
    k=0
    for j in range(len(r)):
        if i!= r.index[k]:
            if r.values[k] >=0.5:
                corr_features.append([i, r.index[k], r.values[k]])
        k += 1
corr_features
# Out:
# [['price', 'bathrooms', 0.5259056214532145],
#  ['price', 'sqft_living', 0.7019173021377597],
#  ['price', 'sqft_above', 0.6053679437051825],
#  ['price', 'sqft_living15', 0.5852412017040677],
#  ['bedrooms', 'bathrooms', 0.5145078282793963],
#  ['bedrooms', 'sqft_living', 0.5782122492779181],
#  ['bathrooms', 'price', 0.5259056214532145],
#  ['bathrooms', 'bedrooms', 0.5145078282793963],
#  ['bathrooms', 'sqft_living', 0.7557576009502674],
#  ['bathrooms', 'floors', 0.502581965656477],
#  ['bathrooms', 'sqft_above', 0.6866677932024619],
#  ['bathrooms', 'yr_built', 0.5071730873365906],
#  ['bathrooms', 'sqft_living15', 0.569883861596954],
#  ['sqft_living', 'price', 0.7019173021377597],
#  ['sqft_living', 'bedrooms', 0.5782122492779181],
#  ['sqft_living', 'bathrooms', 0.7557576009502674],
#  ['sqft_living', 'sqft_above', 0.8764477590354868],
#  ['sqft_living', 'sqft_living15', 0.7564015282474941],
#  ['sqft_lot', 'sqft_lot15', 0.7182040308060962],
# ...

# %%
#plot the frequency of the columns
data.hist(figsize=(30,20))
plt.show()

# %%
# Define a function to detect lower and upper outliers
def detect_outliers(data, column, lower_threshold=1.5, upper_threshold=1.5):
    if np.issubdtype(data[column].dtype, np.number):
        q1 = data[column].quantile(0.25)
        q3 = data[column].quantile(0.75)
        iqr = q3 - q1
        lower_limit = q1 - (lower_threshold * iqr)
        upper_limit = q3 + (upper_threshold * iqr)
        lower_outliers = data[data[column] < lower_limit]
        upper_outliers = data[data[column] > upper_limit]
        return lower_outliers, upper_outliers
    else:
        return pd.DataFrame(), pd.DataFrame()

# Calculate and print total outliers for each column
for column in data.columns:
    lower_outliers, upper_outliers = detect_outliers(data, column)
    total_outliers = len(lower_outliers) + len(upper_outliers)
    print(f"Total outliers in column '{column}': {total_outliers}")
# Out:
# Total outliers in column 'id': 0
# Total outliers in column 'date': 0
# Total outliers in column 'price': 1158
# Total outliers in column 'bedrooms': 530
# Total outliers in column 'bathrooms': 561
# Total outliers in column 'sqft_living': 571
# Total outliers in column 'sqft_lot': 2419
# Total outliers in column 'floors': 0
# Total outliers in column 'waterfront': 0
# Total outliers in column 'view': 0
# Total outliers in column 'condition': 0
# Total outliers in column 'grade': 0
# Total outliers in column 'sqft_above': 610
# Total outliers in column 'sqft_basement': 0
# Total outliers in column 'yr_built': 0
# Total outliers in column 'yr_renovated': 744
# Total outliers in column 'zipcode': 0
# Total outliers in column 'lat': 2
# Total outliers in column 'long': 255
# Total outliers in column 'sqft_living15': 543
# Total outliers in column 'sqft_lot15': 2188

# %%
#It is important to ensure that the data types of each column are appropriate for their respective variables. 
#In this step, we can convert columns to their appropriate data types if needed.
#Looking at the dataset, there are a few columns that might require data type conversions:
#'date': The 'date' column appears to contain date values. We can convert this column to the datetime format for better
#analysis.
#To convert the 'date' column to datetime format, I ran the following command:

data['date'] = pd.to_datetime(data['date'])

#This will convert the 'date' column to datetime format.

# %%
print(data.dtypes)
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront               object
# view                     object
# condition                object
# grade                    object
# sqft_above                int64
# sqft_basement            object
# yr_built                  int64
# yr_renovated            float64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object
